# %% [markdown]
# <img src="https://marketing4ecommerce.net/wp-content/uploads/2015/09/logo-iebs.jpg" style="float:right" width="400">
#
# # Introducción a los lenguajes de programación
#
# ## Caso Práctico: Estudio de un dataset
#
# ### Javier Cózar

# %% [markdown]
# # Dataset
#
# En esta libreta vamos a trabajar con un conjunto de datos obtenido de [Kaggle](https://www.kaggle.com/abecklas/fifa-world-cup?select=WorldCupMatches.csv) que contiene los datos de la FIFA de la copa del mundo. Recomendamos acceder a este enlace para descargar los ficheros a trabajar, aunque también disponéis de los archivos ya descargados en la sección de recursos. Utilizaremos estos tres ficheros:
#
# - WorldCupMatches.csv: Datos de los partidos disputados
# - WorldCupPlayers.csv: Datos de los jugadores que han jugado en cada partido
# - WorldCups.csv: Datos de las copas disputadas y los resultados

# %% [markdown]
# # Importar desde Drive

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Subir contenido del fichero(WorldCups)
#https://drive.google.com/file/d/19yOg3CNfS0NvIPhqz1MaiTIwNzwxjF-f/view?usp=drive_link
link_worldCups = 'https://drive.google.com/open?id=19yOg3CNfS0NvIPhqz1MaiTIwNzwxjF-f'
fluff, id_worldCups = link_worldCups.split('=')
print (id_worldCups)
downloaded = drive.CreateFile({'id':id_worldCups})
downloaded.GetContentFile('WorldCups.csv')

#Subir contenido del fichero(WorldCupPlayers)
#https://drive.google.com/file/d/1EBQkG9a7xjT4i8y8bFT14rszTXBgMXZX/view?usp=drive_link
link_WorldCupPlayers = 'https://drive.google.com/open?id=1EBQkG9a7xjT4i8y8bFT14rszTXBgMXZX'
fluff, id_WorldCupPlayers = link_WorldCupPlayers.split('=')
print (id_WorldCupPlayers)
downloaded = drive.CreateFile({'id':id_WorldCupPlayers})
downloaded.GetContentFile('WorldCupPlayers.csv')

#Subir contenido del fichero(WorldCupMatches)
#https://drive.google.com/file/d/1BUjPGFXs9YWf9wJiKHfCpccs3BW_ThOt/view?usp=drive_link
link_WorldCupMatches = 'https://drive.google.com/open?id=1BUjPGFXs9YWf9wJiKHfCpccs3BW_ThOt'
fluff, id_WorldCupMatches = link_WorldCupMatches.split('=')
print (id_WorldCupMatches)
downloaded = drive.CreateFile({'id':id_WorldCupMatches})
downloaded.GetContentFile('WorldCupMatches.csv')
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive
# 19yOg3CNfS0NvIPhqz1MaiTIwNzwxjF-f
# 1EBQkG9a7xjT4i8y8bFT14rszTXBgMXZX
# 1BUjPGFXs9YWf9wJiKHfCpccs3BW_ThOt

# %% [markdown]
# # Introducción
#
# Mediante esta libreta vamos a explorar los datos almacenados en estos tres ficheros y a responder preguntas haciendo operaciones y transformaciones con pandas. Además de completar las celdas de código para responder a los ejercicios, cuando así se indique se deberá añadir una celda de tipo _markdown_ explicando con texto enriquecido la información o las conclusiones extraídas.

# %%
import pandas as pd

# %%
# Cargamos el conjunto de datos WorldCupMatches
df_partidos = pd.read_csv("WorldCupMatches.csv")

# %% [markdown]
# **NOTA:** en una actividad anterior completamos los ejercicios del 1 al 3, copiar y pegar dicho trabajo en esta libreta con el fin de tener un report completo que analize los datos del problema. Es decir, **no es necesario volver a realizar estos 3 primeros ejercicios**.

# %% [markdown]
# ## 1. Exploración
#
# Usar las funciones `head`, `info` y `describe` para explorar el dataframe `df_partidos`. **Crear una celda de tipo markdown** y comentar brevemente la información almacenada en cada dataframe (columnas y tipo de datos).
#
# _No es necesario hacer una documentación exhaustiva, tan solo comentar aspectos principales como qué tipo de información almacena el DataFrame, cuántas filas y columnas tiene, y comentar las columnas que se consideren más relevantes._

# %% [markdown]
# #### Exploración del DataFrame: `df_partidos`
#
# El DataFrame `df_partidos` contiene información detallada sobre partidos de fútbol. Incluye datos como el año, la fecha y hora del partido, la etapa del torneo, detalles del lugar, nombres de los equipos, puntuaciones y asistencia, entre otros.
#
# **Información General:**
# - Las columnas clave incluyen **(Year, Datetime, Stage, Stadium, City, Home Team Name, Home Team Goals, Away Team Name, Away Team Goals,Attendance)**, e información sobre los oficiales del partido (**Referee, Assistant 1, Assistant 2**).
#
# - Primeras Filas: Los primeros registros muestran detalles como el año del partido, el estadio, la ciudad, los equipos que jugaron, los goles anotados por cada equipo, la asistencia y los árbitros.
#
# -  El DataFrame tiene 4572 filas y 20 columnas.
# - El DatFrame de los 4572 filas , 3735 de ellas estan duplicadas .
# - T
# ipos de datos: de las 20 columnas que compone el dataFrame ,consta con 8 columnas de tipo **float64** y 12 columnas de tipo **Object**.
#
# - Con la función **"df_partidos.isnull().sum()"** , podemos observar que hay 3720 valores nulos en todas en las todas las columnas de nuesto DataFrame excepto la columna de asistencias que tiene 3722, lo cual, podemos concluir que el dataframe consta con filas vacias y hay que tratarlas.
#
#
# - Estadísticas Descriptivas: Las estadísticas muestran que, en promedio, los equipos **locales** anotan 1.81 goles por partido, mientras que los equipos **visitantes** anotan 1.02 goles
# y tambien podemos observar que los equipos **locales** anotan 0.71 goles en el primer tiempo de los 0.43 goles de los los equipos **visitantes** .
# Por otro lado estadisticamente, el promedio de asistencia por partido es de 45164 personas.
# ...

# %%
# Completar
df_partidos.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
# 3                     2549.0                   1.0                   0.0
# 4                    23409.0                   0.0                   0.0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)    201.0   1096.0                FRA
# 1       WARNKEN Alberto (CHI)    201.0   1090.0                USA
# 2         BALWAY Thomas (FRA)    201.0   1093.0                YUG
# 3    MATEUCCI Francisco (URU)    201.0   1098.0                ROU
# 4  RADULESCU Constantin (ROU)    201.0   1085.0                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %%
print("Mostar numeros de filas y columnas")
df_partidos.shape
# Out:
# Mostar numeros de filas y columnas
# (4572, 20)

# %%
print("Mostrar  las primeras filas del DataFrame")
df_partidos.head(2)
# Out:
# Mostrar  las primeras filas del DataFrame
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
#
#                   Referee               Assistant 1            Assistant 2  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)    REGO Gilberto (BRA)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)  WARNKEN Alberto (CHI)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 0    201.0   1096.0                FRA                MEX
# 1    201.0   1090.0                USA                BEL

# %%
print("Mostar estadisticas descriptivas de las columnas numericas del DataFrame")
df_partidos.describe().transpose().round(2)
# Out:
# Mostar estadisticas descriptivas de las columnas numericas del DataFrame
#                       count         mean           std     min       25%  \
# Year                  852.0      1985.09  2.245000e+01  1930.0   1970.00
# Home Team Goals       852.0         1.81  1.610000e+00     0.0      1.00
# Away Team Goals       852.0         1.02  1.090000e+00     0.0      0.00
# Attendance            850.0     45164.80  2.348525e+04  2000.0  30000.00
# Half-time Home Goals  852.0         0.71  9.400000e-01     0.0      0.00
# Half-time Away Goals  852.0         0.43  6.900000e-01     0.0      0.00
# RoundID               852.0  10661772.59  2.729613e+07   201.0    262.00
# MatchID               852.0  61346867.55  1.110572e+08    25.0   1188.75
#
#                           50%          75%          max
# Year                   1990.0      2002.00       2014.0
# Home Team Goals           2.0         3.00         10.0
# Away Team Goals           1.0         2.00          7.0
# Attendance            41579.5     61374.50     173850.0
# Half-time Home Goals      0.0         1.00          6.0
# Half-time Away Goals      0.0         1.00          5.0
# RoundID                 337.0    249722.00   97410600.0
# MatchID                2191.0  43950059.25  300186515.0

# %%
print("Mostrar las ultimas dos filas")
df_partidos.tail(2)
# Out:
# Mostrar las ultimas dos filas
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 4570   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4571   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 4570              NaN            NaN            NaN         NaN
# 4571              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 4570                   NaN                   NaN     NaN         NaN
# 4571                   NaN                   NaN     NaN         NaN
#
#      Assistant 2  RoundID  MatchID Home Team Initials Away Team Initials
# 4570         NaN      NaN      NaN                NaN                NaN
# 4571         NaN      NaN      NaN                NaN                NaN

# %%
print(" Estadísticas descriptivas para las columnas numéricas")
df_partidos.describe()
# Out:
#  Estadísticas descriptivas para las columnas numéricas
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# min                0.000000              0.000000  2.010000e+02  2.500000e+01
# 25%                0.000000              0.000000  2.620000e+02  1.188750e+03
# 50%                0.000000              0.000000  3.370000e+02  2.191000e+03
# 75%                1.000000              1.000000  2.497220e+05  4.395006e+07
# max                6.000000              5.000000  9.741060e+07  3.001865e+08

# %%
print("Mostar el tipo de datos de cada columna en el DataFrame")
df_partidos.dtypes
# Out:
# Mostar el tipo de datos de cada columna en el DataFrame
# Year                    float64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
print("destectar y contar los valores nulos en las columnas del DataFrame")
df_partidos.isnull().sum()
# Out:
# destectar y contar los valores nulos en las columnas del DataFrame
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
print("información general del Daframe")
df_partidos.info()
# Out:
# información general del Daframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
#  14  Assistant 1           852 non-null    object
#  15  Assistant 2           852 non-null    object
#  16  RoundID               852 non-null    float64
#  17  MatchID               852 non-null    float64
#  18  Home Team Initials    852 non-null    object
#  19  Away Team Initials    852 non-null    object
# dtypes: float64(8), object(12)
# memory usage: 714.5+ KB

# %%
print(" Verificar filas duplicadas")
df_partidos.duplicated().sum()
# Out:
#  Verificar filas duplicadas
# 3735

# %%
print("contar el número de valores no nulos en cada columna del DataFrame")
df_partidos.count()
# Out:
# contar el número de valores no nulos en cada columna del DataFrame
# Year                    852
# Datetime                852
# Stage                   852
# Stadium                 852
# City                    852
# Home Team Name          852
# Home Team Goals         852
# Away Team Goals         852
# Away Team Name          852
# Win conditions          852
# Attendance              850
# Half-time Home Goals    852
# Half-time Away Goals    852
# Referee                 852
# Assistant 1             852
# Assistant 2             852
# RoundID                 852
# MatchID                 852
# Home Team Initials      852
# Away Team Initials      852
# dtype: int64

# %% [markdown]
# ## 2. Limpieza de datos
#
# Una de las cosas que llama la atención es la alta presencia de valores perdidos en el DataFrame `df_partidos`. Cuando trabajamos con datos obtenidos del mundo real siempre nos toparemos con problemas relacionados con la medición, captura o almacenamiento de dicha información.
#
# Localiza las filas con valores perdido. Analizar y **documentar en una nueva celda de tipo markdown** a qué se deben estos valores perdidos. Finalmente usar la función [dropna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) sobre el DataFrame `df_partidos` para eliminar los valores perdidos del DataFrame, y almacena el resultado en `df_partidos` de nuevo.

# %% [markdown]
#  * **Tras el el analisis realizado al DataFrame de df_partidos que se muestra a continuación, he realizando las siguientes funcionen para ganrantizar la calidad de los datos y consistencia de los mismos mediante la eleminación de valores perdidos , el manejo de valores nulos y la remoción de duplicados en el DataFrame.** *
#
#   Los valores perdidos en el dataframe puede deberse a como se obtuvieron los datos durante la recopitalación.

# %% [markdown]
# 1.  Identificación y eliminación de valores nulos
#
#     Con la siguiente funcion se observa la presencia de valores  de varias filas completamente nulos (NaN) en el DataFrame.

# %%
df_partidos[df_partidos.isna().all(axis=1)].head(2)
# Out:
#      Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 852   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 853   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#      Away Team Goals Away Team Name Win conditions  Attendance  \
# 852              NaN            NaN            NaN         NaN
# 853              NaN            NaN            NaN         NaN
#
#      Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 852                   NaN                   NaN     NaN         NaN
# 853                   NaN                   NaN     NaN         NaN
#
#     Assistant 2  RoundID  MatchID Home Team Initials Away Team Initials
# 852         NaN      NaN      NaN                NaN                NaN
# 853         NaN      NaN      NaN                NaN                NaN

# %%
df_partidos.shape
# Out:
# (4572, 20)

# %% [markdown]
# 2.   Elemincación de filas Nulos
#
#   Se utiliza la función **dropna()** para eliminar filas donde todos los valores de las columnas son nulos, se vuelve a guardar en la variable **df_partidos**

# %%
df_partidos = df_partidos.dropna(how='all')

# %% [markdown]
#  3. Tratamiento de columna Attendance
#
#   Haciendo uso de la funcion **df_partidos.isnull().sum()** , se observa que quitando las filas nulos ,  hay dos valores nulos en la columna **attendance**

# %% [markdown]
# ```
# # Tiene formato de código
# ```
#
#
#
# *   Se filtra los registros con valores nulos en la columna Attendance

# %%
df_partidos.loc[df_partidos.Attendance.isna()]
# Out:
#        Year              Datetime        Stage            Stadium  \
# 823  2014.0  30 Jun 2014 - 17:00   Round of 16  Estadio Beira-Rio
# 841  2014.0  30 Jun 2014 - 17:00   Round of 16  Estadio Beira-Rio
#
#               City Home Team Name  Home Team Goals  Away Team Goals  \
# 823  Porto Alegre         Germany              2.0              1.0
# 841  Porto Alegre         Germany              2.0              1.0
#
#     Away Team Name                 Win conditions  Attendance  \
# 823        Algeria  Germany win after extra time          NaN
# 841        Algeria  Germany win after extra time          NaN
#
#      Half-time Home Goals  Half-time Away Goals             Referee  \
# 823                   0.0                   0.0  RICCI Sandro (BRA)
# 841                   0.0                   0.0  RICCI Sandro (BRA)
#
#                    Assistant 1              Assistant 2   RoundID  \
# 823  DE CARVALHO Emerson (BRA)  VAN GASSE Marcelo (BRA)  255951.0
# 841  DE CARVALHO Emerson (BRA)  VAN GASSE Marcelo (BRA)  255951.0
#
#          MatchID Home Team Initials Away Team Initials
# 823  300186460.0                GER                ALG
# 841  300186460.0                GER                ALG

# %% [markdown]
# *  Utilizando fillna(), se rellena con la mediana de los valores no nulos, es decir , en los dos partidos en el que no hubo asistencia se completa con la mediana de asistencia de la suma de todos los partidos jugados

# %%
df_partidos["Attendance"] = df_partidos["Attendance"].fillna(df_partidos.Attendance.mean())
# Out:
# <ipython-input-19-86d83755fd5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_partidos["Attendance"] = df_partidos["Attendance"].fillna(df_partidos.Attendance.mean())

# %%
df_partidos.loc[df_partidos.Attendance.isna()]
# Out:
# Empty DataFrame
# Columns: [Year, Datetime, Stage, Stadium, City, Home Team Name, Home Team Goals, Away Team Goals, Away Team Name, Win conditions, Attendance, Half-time Home Goals, Half-time Away Goals, Referee, Assistant 1, Assistant 2, RoundID, MatchID, Home Team Initials, Away Team Initials]
# Index: []

# %% [markdown]
# *   Listando los dos partidos donde no hubo asistencia podemos observar que efectivamente se ha rellenado con la media de las asistencias.

# %%
df = df_partidos.loc[df_partidos.MatchID.round() == 300186460]
df = df[['MatchID', 'Attendance']]
df
# Out:
#          MatchID  Attendance
# 823  300186460.0     45164.8
# 841  300186460.0     45164.8

# %% [markdown]
# *   Y con la siguiente función validamos que se han tratado correctameente los valores nulos de nuestro DataFrame df_partidos

# %%
filas_vacias = df_partidos[df_partidos.isna().any(axis=1)]
filas_vacias.head()
# Out:
# Empty DataFrame
# Columns: [Year, Datetime, Stage, Stadium, City, Home Team Name, Home Team Goals, Away Team Goals, Away Team Name, Win conditions, Attendance, Half-time Home Goals, Half-time Away Goals, Referee, Assistant 1, Assistant 2, RoundID, MatchID, Home Team Initials, Away Team Initials]
# Index: []

# %% [markdown]
#  4. Tratamiento de registros duplicados:
#
#
#   *  Mediante la funcion **duplicated()** , contamos y indentificamos los registros duplicados

# %%
df_partidos.duplicated().sum()
# Out:
# 16

# %%
df_partidos[df_partidos.duplicated()].head(2)
# Out:
#        Year              Datetime        Stage              Stadium  \
# 836  2014.0  28 Jun 2014 - 13:00   Round of 16     Estadio Mineirao
# 837  2014.0  28 Jun 2014 - 17:00   Round of 16  Estadio do Maracana
#
#                 City Home Team Name  Home Team Goals  Away Team Goals  \
# 836  Belo Horizonte          Brazil              1.0              1.0
# 837  Rio De Janeiro        Colombia              2.0              0.0
#
#     Away Team Name                    Win conditions  Attendance  \
# 836          Chile  Brazil win on penalties (3 - 2)      57714.0
# 837        Uruguay                                       73804.0
#
#      Half-time Home Goals  Half-time Away Goals              Referee  \
# 836                   0.0                   0.0    WEBB Howard (ENG)
# 837                   1.0                   0.0  Bj�rn KUIPERS (NED)
#
#                  Assistant 1           Assistant 2   RoundID      MatchID  \
# 836  MULLARKEY Michael (ENG)     Darren CANN (ENG)  255951.0  300186487.0
# 837  Sander VAN ROEKEL (NED)  Erwin ZEINSTRA (NED)  255951.0  300186491.0
#
#     Home Team Initials Away Team Initials
# 836                BRA                CHI
# 837                COL                URU

# %% [markdown]
# *   Posteriormente, se eliminaron registros duplicados utilizando **drop_duplicates()**, manteniendo únicamente la última aparición de cada registro **(keep='last')**, para asegurar que los datos sean únicos y relevantes.

# %%
df_partidos = df_partidos.drop_duplicates(keep='last')
df_partidos.drop_duplicates(inplace=True)
# Out:
# <ipython-input-25-4ff4cbe0978d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_partidos.drop_duplicates(inplace=True)

# %%
df_partidos = df_partidos.drop_duplicates()
df_partidos.drop_duplicates(inplace=True)

# %%
df_partidos[df_partidos.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year, Datetime, Stage, Stadium, City, Home Team Name, Home Team Goals, Away Team Goals, Away Team Name, Win conditions, Attendance, Half-time Home Goals, Half-time Away Goals, Referee, Assistant 1, Assistant 2, RoundID, MatchID, Home Team Initials, Away Team Initials]
# Index: []

# %% [markdown]
# ## 3. Cargar datos
#
# Al igual que hemos cargado los datos de los partidos en `df_partidos`, crear las variables `df_jugadores` y `df_copas` que contengan los dataframes correspondientes a la lectura de los csv `WorldCupPlayers` y `WorldCups` (usar `pd.read_csv)`.

# %%
# Completar
# Cargamos el conjunto de datos WorldCupMatches
df_jugadores = pd.read_csv("WorldCupPlayers.csv")

# %%
# Cargamos el conjunto de datos WorldCupMatches
df_copas = pd.read_csv("WorldCups.csv")

# %%
df_jugadores.head(1)
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#    Player Name Position Event
# 0  Alex THEPOT       GK   NaN

# %%
df_copas.head(1)
# Out:
#    Year  Country   Winner Runners-Up Third      Fourth  GoalsScored  \
# 0  1930  Uruguay  Uruguay  Argentina   USA  Yugoslavia           70
#
#    QualifiedTeams  MatchesPlayed Attendance
# 0              13             18    590.549

# %% [markdown]
# ## 4. Rango temporal
#
# El dataframe `df_copas` contiene datos de todos los mundiales disputados. ¿Cuál es el año del mundial más antiguo disputado? ¿Y el año del mundial más reciente?
#
# **Pista:** recuerda que podemos usar funciones de agregación (`count` para contar el número de casos, `mean` para calcular el valor medio, etc.) directamente sobre columnas o Series de pandas. Por ejemplo, el siguiente código nos muestra el mayor número de goles marcado en un mundial.
#
# ```python
# df_copas["GoalsScored"].max()
# ```
#
# **Opcional:** Una vez localizados los años de interés (más antiguo y más reciente) visualizar las filas completas correspondientes a cada año usando la función `.loc`.

# %%
maxyearMundial = df_copas.agg({'Year':'max'})
max = df_copas["Year"].max()
print(f"El mundial más reciente se  disputado en el año {max}")
min = df_copas["Year"].min()
print(f"El mundial más antiguo se  disputado en el año {min}")
print("\n")
minyearMundial = df_copas.agg({'Year':'min'})

print(f"El mundial más antiguo se  disputado en el {minyearMundial} Y el más reciente en el {maxyearMundial}")
# Out:
# El mundial más reciente se  disputado en el año 2014
# El mundial más antiguo se  disputado en el año 1930
#
#
# El mundial más antiguo se  disputado en el Year    1930
# dtype: int64 Y el más reciente en el Year    2014
# dtype: int64

# %% [markdown]
# Filas del mundial más reciente y del mundial mas antiguo disputado

# %%
df_copas.loc[(df_copas['Year'] == max) | (df_copas['Year'] == min)]
# Out:
#     Year  Country   Winner Runners-Up        Third      Fourth  GoalsScored  \
# 0   1930  Uruguay  Uruguay  Argentina          USA  Yugoslavia           70
# 19  2014   Brazil  Germany  Argentina  Netherlands      Brazil          171
#
#     QualifiedTeams  MatchesPlayed Attendance
# 0               13             18    590.549
# 19              32             64  3.386.810

# %% [markdown]
# ---
# # Ejercicios a realizar
#
# Los ejercicios a continuación amplian el reporte comenzado en una actividad semanal anterior. Algunos de ellos son más complejos y son opcionales, pero se recomienda que al menos se intente resolverlos pues puntuará positivamente.
#
# ---

# %% [markdown]
# # Cargar DF

# %%
import pandas as pd
# Cargamos el conjunto de datos WorldCupMatches
df_partidos = pd.read_csv("WorldCupMatches.csv")
# Cargamos el conjunto de datos WorldCupMatches
df_jugadores = pd.read_csv("WorldCupPlayers.csv")
# Cargamos el conjunto de datos WorldCupMatches
df_copas = pd.read_csv("WorldCups.csv", thousands=".")

# %% [markdown]
# ## 5. Asistencia de público
#
# La columna `Attendance` indica la asistencia de público en cada mundial. Pandas ha cargado esta columna como tipo string, ya que los valores indicados contienen puntos como separador de millares. En primer lugar vamos a transformar esta columna para que no contenga el caracter `.`. Posteriormente transformaremos esta columna a formato numérico usando la función [pd.to_numeric](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_numeric.html).
#
# **Nota**: la función `pd.read_csv` también permite hacer este proceso de una forma mucho más transparente, usando el argumento `thousands`. Ver la documentación [aquí](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).

# %%
#df_copas["Attendance"] = pd.to_numeric(df_copas["Attendance"].str.replace(".", ""))
#df_copas = pd.read_csv("WorldCups.csv", thousands=".")

# %% [markdown]
# Teniendo en cuenta todos los datos de `df_copas`, ¿Cuál fué la mayor asistencia de un mundial? ¿Cuál es la asistencia media?

# %%
df_copas.head(5)
max_asistencia = df_copas["Attendance"].max()
print(f"La mayor asistencia de un mundial fue de {max_asistencia} espectadores.")
media_asistencia = df_copas["Attendance"].mean()
print(f"La asistencia media de un mundial fue de {media_asistencia} espectadores.")
print("\n")
print("Comprobacion manual")
print("-----------------")
sum_asistencia = df_copas["Attendance"].sum()
print(f"La suma de las asistencia de todos los mundiales jugados fue de {sum_asistencia} espectadores.")
num_cpus = df_copas["Attendance"].count()
print(f"El número de mundiales jugados fue de {num_cpus} mundiales.")
print(f"La asistencia media de un mundial fue de {sum_asistencia/num_cpus} espectadores.")
# Out:
# La mayor asistencia de un mundial fue de 3587538 espectadores.
# La asistencia media de un mundial fue de 1872882.35 espectadores.
#
#
# Comprobacion manual
# -----------------
# La suma de las asistencia de todos los mundiales jugados fue de 37457647 espectadores.
# El número de mundiales jugados fue de 20 mundiales.
# La asistencia media de un mundial fue de 1872882.35 espectadores.

# %% [markdown]
# ## 6. Asistencia de público en función del país
#
# Sabemos que, dependiendo del país donde se celebre la copa del mundo, ésta tiene un mayor o menor impacto o relevancia. Vamos a calcular la media de asistencia agrupando por país. Finalmente, ordenar los resultados por orden decreciente de este número medio de asistentes.
#
# **Pista 1:** Como se muestra en el siguiente ejemplo, recuerda que podemos combinar la función [groupby](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html) con otras funciones de agregación como `mean`.
#
# **Pista 2:** Recuerda que podemos usar la función [sort_values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html) para ordenar un DataFrame por una de sus columnas. Por ejemplo, el siguiente código muestra los mundiales ordenados de forma decreciente por el número de goles marcados:
#
# ```python
# df_copas.sort_values("GoalsScored", ascending=False)
# ```

# %% [markdown]
# La media de asistencia por país ordenado de mayor a menor

# %%
df_copas.groupby("Country")["Attendance"].mean().rename("media_asistencia").sort_values(ascending=False).head(10)
# Out:
# Country
# USA             3587538.0
# South Africa    3178856.0
# Korea/Japan     2705197.0
# Germany         2612596.0
# Brazil          2216028.0
# Spain           2109723.0
# Mexico          1999003.0
# France          1580400.0
# England         1563135.0
# Argentina       1545791.0
# Name: media_asistencia, dtype: float64

# %% [markdown]
# ## 7. País con más victorias
#
# Vamos a analizar el número de veces que un país ha ganado la copa del mundo. Transformar el DataFrame `df_copas` para que muestre los diferentes países que han ganado al menos una copa del mundo, y ordena el DataFrame por dicho número de forma descendente usando la función [sort_values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html).
#
# ¿Ves algo extraño o digno de comentar? Pista: analiza Alemania. **Hazlo en una nueva celda de tipo markdown.**

# %% [markdown]
# Analizando Alemania vemos que tiene que hay incocurencia en los datos, lo cual vamos a actualizar Germany FR a Germany

# %%
df_copas.loc[df_copas["Winner"].str.contains("Germany", case=False)].groupby("Winner")["Winner"].count().rename("victorias").sort_values(ascending=False)
# Out:
# Winner
# Germany FR    3
# Germany       1
# Name: victorias, dtype: int64

# %% [markdown]
# Cambiar Germany FR a Germany

# %%
df_copas["Winner"] = df_copas["Winner"].replace("Germany FR", "Germany")
df_copas.loc[df_copas["Winner"].str.contains("Germany", case=False)]
# Out:
#     Year      Country   Winner   Runners-Up        Third   Fourth  \
# 4   1954  Switzerland  Germany      Hungary      Austria  Uruguay
# 9   1974      Germany  Germany  Netherlands       Poland   Brazil
# 13  1990        Italy  Germany    Argentina        Italy  England
# 19  2014       Brazil  Germany    Argentina  Netherlands   Brazil
#
#     GoalsScored  QualifiedTeams  MatchesPlayed  Attendance
# 4           140              16             26      768607
# 9            97              16             38     1865753
# 13          115              24             52     2516215
# 19          171              32             64     3386810

# %% [markdown]
# Mostar los paises que mas han levantado la copa del mundo de los que mas a los que menos lo han levantado

# %%
df_copas.groupby("Winner")["Winner"].count().rename("victorias").sort_values(ascending=False)
# Out:
# Winner
# Brazil       5
# Germany      4
# Italy        4
# Argentina    2
# Uruguay      2
# England      1
# France       1
# Spain        1
# Name: victorias, dtype: int64

# %% [markdown]
# Otras alternativa para mostrar aquellos paises que nunca han levantado la copa del mundo hasta los que mas lo han levando

# %%
#para ello listamos todos paises que han jugado al menos un mundial
dfpais = df_copas["Country"]

# %%
#después listamos los paises que al menos al ganado la copa del mundo
dfganadores = df_copas["Winner"]

# %%
#Y concadenamos el listado de los paises obtenidos anteriormente para obtener la lista de todos los paises(Ganadores y no ganadores) y dropduplicates para eleminar paises duplicados
listado_paises = pd.concat([dfpais.rename("Country"),dfganadores.rename("Country")]).drop_duplicates()

# %%
#Y por ulitmo con la funcion merge cruzamos la lista de todos paises contra los paises que ganadores y ordenar de forma ascendiente para determinar los paises que nunca que ganado al los que mas han ganado
pd.merge(listado_paises,dfganadores, left_on="Country", right_on="Winner", how='outer').groupby("Country")["Winner"].count().rename("victorias").sort_values(ascending=True).head(10)
# Out:
# Country
# Chile           0
# Korea/Japan     0
# Mexico          0
# South Africa    0
# Sweden          0
# Switzerland     0
# USA             0
# England         1
# France          1
# Spain           1
# Name: victorias, dtype: int64

# %%
pd.merge(listado_paises,dfganadores, left_on="Country", right_on="Winner", how='outer').groupby("Country")["Winner"].count().rename("victorias").sort_values(ascending=False).head(5)
# Out:
# Country
# Brazil       5
# Germany      4
# Italy        4
# Argentina    2
# Uruguay      2
# Name: victorias, dtype: int64

# %% [markdown]
# ---
# # Parte opcional
#
# Los ejercicios anteriores son obligatorios y puntuan hasta un máximo de 80 puntos sobre 100.
#
# Los siguientes ejercicios trabajan con los dataframes cargados para extraer información concreta a partir de los datos.
# Estos ejercicios son opcionales, pero es recomendable intentar resolverlos para adquirir habilidades.
#
# ---

# %% [markdown]
# ## Creación de un nuevo DataFrame
#
# A continuación vamos a trabajar con el DataFrame `df_partidos`. Vamos a centrarnos en la información a nivel de selección, siendo indiferente si el equipo juega en casa o fuera. En este sentido, la información disponible no es la mejor para trabajar cómodamente. Por ello, es habitual realizar transformaciones a los datos en función de las preguntas que le queramos hacer. A continuación crearemos un nuevo DataFrame llamado `df_paises`que contendrá todos los paises involucrados en la copa del mundo y el año en el que participaron. Es decir, un país que haya jugado varias copas del mundo aparecerá varias veces:
#
#
# ||Year|Country|
# |---|---|---|
# |0|1930|France|
# |1|1930|USA|
# |...|...|..|
# |37|1938|France|
# |...|...|..|
#
# **Nota:** este problema se puede afrontar como mínimo de dos maneras diferentes
#
# 1. Generando dos dataframes, uno donde la columna `Country` se corresponde con `Home Team Name`, y otro donde la columna `Country` se corresponde con `Away Team Name`. Finalmente, combinar ambos DataFrames en uno solo.
# 2. Usar la función [melt](https://pandas.pydata.org/docs/reference/api/pandas.melt.html) que nos permite convertir N columnas en un par de columnas llamadas `variable` y `value`, donde la primera es el nombre de una de las columnas y `value` el valor que tomó dicha variable.

# %%
#alternativa 1
df_paises = (
    pd.concat([
        df_partidos[["Year", "Home Team Name"]].rename(columns={"Home Team Name": "Country"}),
        df_partidos[["Year", "Away Team Name"]].rename(columns={"Away Team Name": "Country"})
    ])
)
#alternativa 2
df_paises = (
    df_partidos
    .melt(id_vars=["Year"], value_vars=["Home Team Name", "Away Team Name"])
    .rename(columns={"value": "Country"})
    [["Year", "Country"]]
)

# %%
df_partidos.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
df_paises = (
    pd.concat([
        df_partidos[["Year", "Home Team Name"]].rename(columns={"Home Team Name": "Country"}),
        df_partidos[["Year", "Away Team Name"]].rename(columns={"Away Team Name": "Country"})
    ])
)

# %%
df_paises["Country"] = df_paises["Country"].replace("Germany FR", "Germany")

# %%
df_paises.count()
# Out:
# Year       1704
# Country    1704
# dtype: int64

# %%
df_paises.head(2)
# Out:
#      Year Country
# 0  1930.0  France
# 1  1930.0     USA

# %% [markdown]
# ## 8. Número de países
#
# Vamos a descubrir cuántos países han participado, al menos una vez, en una copa del mundo. Para ello vamos a trabajar con el DataFrame construido anteriormente y a usar la función de agregación [nunique](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.nunique.html).

# %%
df_paises["Country"].drop_duplicates().count()
# Out:
# 82

# %%
df_paises["Country"].nunique()
# Out:
# 82

# %% [markdown]
# ## 9. Número de partidos por país
#
# Ahora vamos a descubrir cuántos partidos ha jugado cada país. Operar con el DataFrame para que muestre un país por fila y una columna que indique el número de partidos que ha jugado. Ordenar el DataFrame por dicha columna de forma descendente.

# %%
listadopaises = df_paises["Country"].rename("listCountry").drop_duplicates()

# %%
df = pd.merge(listadopaises,df_paises, left_on="listCountry", right_on="Country", how='outer').groupby("listCountry")["Country"].count().rename("partidos").sort_values(ascending=False)

# %%
df
# Out:
# listCountry
# Germany                     110
# Brazil                      108
# Italy                        83
# Argentina                    81
# England                      62
#                            ...
# Kuwait                        3
# Iraq                          3
# Serbia                        3
# rn">United Arab Emirates      3
# Dutch East Indies             1
# Name: partidos, Length: 82, dtype: int64

# %%
df = pd.merge(listadopaises,df_paises, left_on="listCountry", right_on="Country", how='outer').groupby("listCountry")["Country"].count().rename("partidos").sort_values(ascending=True)

# %%
df
# Out:
# listCountry
# Dutch East Indies             1
# rn">United Arab Emirates      3
# Haiti                         3
# Iraq                          3
# Israel                        3
#                            ...
# England                      62
# Argentina                    81
# Italy                        83
# Brazil                      108
# Germany                     110
# Name: partidos, Length: 82, dtype: int64

# %% [markdown]
# ## 10. Partidos jugados por España
#
# Vamos a trabajar a continuación con el DataFrame `df_partidos`. Seleccionar aquellos partidos (filas del dataframe) en los que España ha jugado como `Home Team`, es decir, donde la columna `Home Team` tiene el valor `España`. Recuerda que para la operación de filtrado hay que usar la función [.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html).
#
#
# A continuación, haz una nueva selección en los que España ha jugado como `Away Team`, es decir, donde la columna `Away Team` tiene el valor `España`.
#
# **Opcional:** ¿Podrías hacer una sola selección donde España haya jugado como `Home Team` o como `Away Team`?. Pista: consulta la documentación del operador de [disyunción](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#boolean-indexing).

# %%
#DF en los que España ha jugado como Home Team
df_partidos.loc[df_partidos["Home Team Name"] == "Spain"].head(1)
# Out:
#       Year              Datetime              Stage         Stadium    City  \
# 23  1934.0  27 May 1934 - 16:30   Preliminary round  Luigi Ferraris  Genoa
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 23          Spain              3.0              1.0         Brazil
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 23                    21000.0                   3.0                   0.0
#
#                 Referee             Assistant 1             Assistant 2  \
# 23  BIRLEM Alfred (GER)  CARMINATI Ettore (ITA)  IVANCSICS Mihaly (HUN)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 23    204.0   1111.0                ESP                BRA

# %%
#DF en los que España ha jugado como Away Team Name
df_partidos.loc[df_partidos["Away Team Name"] == "Spain"].head(1)
# Out:
#       Year              Datetime           Stage         Stadium       City  \
# 28  1934.0  31 May 1934 - 16:30   Quarter-finals  Giovanni Berta  Florence
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 28          Italy              1.0              1.0          Spain
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 28                    35000.0                   0.0                   0.0
#
#               Referee            Assistant 1             Assistant 2  RoundID  \
# 28  BAERT Louis (BEL)  ZENISEK Bohumil (TCH)  IVANCSICS Mihaly (HUN)    418.0
#
#     MatchID Home Team Initials Away Team Initials
# 28   1122.0                ITA                ESP

# %%
#DF en los que España ha jugado como Away Team Name y como Home Team
df_partidos.loc[(df_partidos["Home Team Name"] == "Spain") | (df_partidos["Away Team Name"] == "Spain")].head(2)
# Out:
#       Year              Datetime              Stage         Stadium  \
# 23  1934.0  27 May 1934 - 16:30   Preliminary round  Luigi Ferraris
# 28  1934.0  31 May 1934 - 16:30      Quarter-finals  Giovanni Berta
#
#          City Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 23     Genoa           Spain              3.0              1.0         Brazil
# 28  Florence           Italy              1.0              1.0          Spain
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 23                    21000.0                   3.0                   0.0
# 28                    35000.0                   0.0                   0.0
#
#                 Referee             Assistant 1             Assistant 2  \
# 23  BIRLEM Alfred (GER)  CARMINATI Ettore (ITA)  IVANCSICS Mihaly (HUN)
# 28    BAERT Louis (BEL)   ZENISEK Bohumil (TCH)  IVANCSICS Mihaly (HUN)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 23    204.0   1111.0                ESP                BRA
# 28    418.0   1122.0                ITA                ESP

# %%
#Otra alternativa, DF en los que España ha jugado como Away Team Name y como Home Team
pd.concat([df_partidos.loc[df_partidos["Home Team Name"] == "Spain"],df_partidos.loc[df_partidos["Away Team Name"] == "Spain"]]).drop_duplicates().head(2)
# Out:
#       Year              Datetime              Stage           Stadium  \
# 23  1934.0  27 May 1934 - 16:30   Preliminary round    Luigi Ferraris
# 55  1950.0  25 Jun 1950 - 15:00             Group 2  Durival de Brito
#
#          City Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 23     Genoa           Spain              3.0              1.0         Brazil
# 55  Curitiba           Spain              3.0              1.0            USA
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 23                    21000.0                   3.0                   0.0
# 55                     9511.0                   0.0                   1.0
#
#                 Referee                 Assistant 1  \
# 23  BIRLEM Alfred (GER)      CARMINATI Ettore (ITA)
# 55    VIANA Mario (BRA)  DA COSTA VIEIRA Jose (POR)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 23     IVANCSICS Mihaly (HUN)    204.0   1111.0                ESP
# 55  DE LA SALLE Charles (FRA)    208.0   1208.0                ESP
#
#    Away Team Initials
# 23                BRA
# 55                USA

# %% [markdown]
# ## Calcular el vencedor de cada partido
#
# El DataFrame `df_partidos` tiene la información de cada partido, incluyendo los goles marcados por cada equipo, pero no disponemos de una columna que indique si un equipo ganó o perdió. Vamos a crear una columna llamada `Ganador` que indique el nombre del equipo vencedor (con más goles). También podemos encontrar empates, en cuyo caso usaremos `pd.NA` para indicar que desconocemos el vencedor de dicho partido.
#
# **Nota:** Se puede resolver realizando varias asignaciones, o una sola utilizando la función [pd.where](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.where.html).

# %%
# alternativa 1
df_partidos["Ganador"] = df_partidos["Home Team Name"]
df_partidos.loc[df_partidos["Home Team Goals"] < df_partidos["Away Team Goals"], "Ganador"] = df_partidos["Away Team Name"]
df_partidos.loc[df_partidos["Home Team Goals"] == df_partidos["Away Team Goals"], "Ganador"] = pd.NA

# alternativa 2
df_partidos["Ganador"] = (
    df_partidos["Home Team Name"].where(
        df_partidos["Home Team Goals"] > df_partidos["Away Team Goals"],
        df_partidos["Away Team Name"].where(df_partidos["Home Team Goals"] < df_partidos["Away Team Goals"], pd.NA)
    )
)

# %% [markdown]
# ## 11. Número de victorias por país
#
# Calcular para cada país el número de partidos ganados. Para ello, usar la función [dropna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) para eliminar las filas correspondientes a partidos donde la columna `Ganador` es un valor perdido (`na`). Ordenar los países por número de victorias de forma descendente.

# %%
df_partidos["Ganador"] = df_partidos["Ganador"].replace("Germany FR", "Germany")
df_partidos.dropna(subset=["Ganador"]).groupby("Ganador")["Ganador"].count().rename("victorias").sort_values(ascending=False)
# Out:
# Ganador
# Brazil                        71
# Germany                       70
# Italy                         45
# Argentina                     44
# France                        29
#                               ..
# Cuba                           1
# Korea DPR                      1
# Wales                          1
# rn">Bosnia and Herzegovina     1
# Iran                           1
# Name: victorias, Length: 63, dtype: int64

# %% [markdown]
# ## Opcional 1
#
# Calcular para cada país el ratio de victorias, calculado como el número de partidos ganados dividido por el número de partidos jugados. Ordenar los países por ratio de forma descendente.
#
# **Pista:** Si obtenemos dos dataframes, uno con las victorias por cada país y otro con el número total de partidos jugados, podemos utilizar la función [pd.merge](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html) para combinar ambos en un solo DataFrame, y despues crear una nueva columna que sea el ratio.

# %%
df_victorias = df_partidos.dropna(subset=["Ganador"]).groupby("Ganador")["Ganador"].count().rename("victorias").sort_values(ascending=False)
df_partidos_jugados = df_paises.groupby("Country")["Country"].count().rename("partidos").sort_values(ascending=False)
df_radio = pd.merge(df_victorias, df_partidos_jugados, left_index=True, right_index=True)
df_radio["ratio"] = df_radio["victorias"] / df_radio["partidos"]
df_radio
# Out:
#                             victorias  partidos     ratio
# Brazil                             71       108  0.657407
# Germany                            70       110  0.636364
# Italy                              45        83  0.542169
# Argentina                          44        81  0.543210
# France                             29        61  0.475410
# ...                               ...       ...       ...
# Cuba                                1         3  0.333333
# Korea DPR                           1         7  0.142857
# Wales                               1         5  0.200000
# rn">Bosnia and Herzegovina          1         3  0.333333
# Iran                                1         6  0.166667
#
# [63 rows x 3 columns]

# %% [markdown]
# ## Opcional 2
#
# ¿Se te ocurre alguna pregunta adicional que hacerle a los datos? Utiliza una celda de tipo markdown para documentarla y otra de código para implementarla y ver así la respuesta.

# %% [markdown]
# Mostrar el numero de partidos por cada jugador de cada pais en cada uno
# de los mundiales disputados

# %%
#En primer lugar listados de todos los partidos jugados (extrayendo unicamente las columnas mas relevnates como el año del mundial, los paiese y el indentificador el partido jugado)
df_partidosJugados = (
    pd.concat([
        df_partidos[["Year", "Home Team Name","MatchID"]].rename(columns={"Home Team Name": "Country"}),
        df_partidos[["Year", "Away Team Name","MatchID"]].rename(columns={"Away Team Name": "Country"}) ])).dropna(how='all')

# %%
#volvemos actualar Germany FR
df_partidosJugados["Country"] = df_partidosJugados["Country"].replace("Germany FR", "Germany")

# %%
#despues determinamos la relación jugador y partidos jugados
df_jugadores = df_partidosJugados.merge(df_jugadores, left_on=["MatchID"], right_on=["MatchID"], how='outer')

# %%
#Y por ultimos se agrupa por el año del mundial , pais y por el nombre el jugador y posteriomente se cuenta el numeros de veces que um jugador ha participado en un partido de un mundial
dfSumpartidosJugados = df_jugadores.groupby(["Year","Country","Player Name"])["Player Name"].count().rename("NumpartidosJugados").sort_values(ascending=False)

# %%
#mostrar(Podemos observar que Brasil y Alemania son los paises cuyo jugadores tienes mas participaciones en mundiales)
dfSumpartidosJugados
# Out:
# Year    Country         Player Name
# 2014.0  Brazil          DANTE                  19
#                         J�                     19
#         Germany         KRAMER                 19
#                         KROOS                  19
#                         LAHM                   19
#                                                ..
# 1986.0  Morocco         Zbigniew BONIEK         1
#                         Wolfgang ROLFF          1
#                         Wlodimierz SMOLAREK     1
#                         Wladyslaw ZMUDA         1
# 1990.0  Czechoslovakia  David VANOLE            1
# Name: NumpartidosJugados, Length: 45809, dtype: int64

# %%
df_jugadores["MatchID"].loc[df_jugadores["Country"]=="Brazil"].loc[df_jugadores["Year"]==2014].loc[df_jugadores["Player Name"]=="DANI ALVES"].count()
# Out:
# 19
